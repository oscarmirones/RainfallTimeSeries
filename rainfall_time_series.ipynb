# %%
from matplotlib.pylab import *
import pandas as pd
import matplotlib.dates as dates
import seaborn as sns

# %% [markdown]
# # San Diego, California

# %%
serie = pd.read_csv('san_diego.csv')
serie
# Out:
#                       Time  Precipitation
# 0      1998-01-01 00:00:00            0.0
# 1      1998-01-01 03:00:00            0.0
# 2      1998-01-01 06:00:00            0.0
# 3      1998-01-01 09:00:00            0.0
# 4      1998-01-01 12:00:00            0.0
# ...                    ...            ...
# 63292  2019-08-30 12:00:00            0.0
# 63293  2019-08-30 15:00:00            0.0
# 63294  2019-08-30 18:00:00            0.0
# 63295  2019-08-30 21:00:00            0.0
# 63296  2019-08-31 00:00:00            0.0
#
# [63297 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
fig, ax = plt.subplots()
ax.plot_date(pd.to_datetime(serie['Time']), serie.Precipitation, '-')
ax.xaxis.set_major_locator(dates.YearLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y'))
plt.tight_layout()
plt.title("San Diego's Rainfall 1998-2019")
plt.show()

# %% [markdown]
# # Kwajalein, Republica de las Islas Marshall

# %%
serie = pd.read_csv('kwajalein.csv')
serie
# Out:
#                       Time  Precipitation
# 0      1998-01-01 00:00:00           0.06
# 1      1998-01-01 03:00:00           0.08
# 2      1998-01-01 06:00:00           0.00
# 3      1998-01-01 09:00:00           0.00
# 4      1998-01-01 12:00:00           0.26
# ...                    ...            ...
# 63292  2019-08-30 12:00:00           0.00
# 63293  2019-08-30 15:00:00           0.00
# 63294  2019-08-30 18:00:00           2.63
# 63295  2019-08-30 21:00:00           0.00
# 63296  2019-08-31 00:00:00           0.00
#
# [63297 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
fig, ax = plt.subplots()
ax.plot_date(pd.to_datetime(serie['Time']), serie.Precipitation, '-')
ax.xaxis.set_major_locator(dates.YearLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y'))
plt.tight_layout()
plt.title("Kwajalein's Rainfall 1998-2019")
plt.show()

# %% [markdown]
# # Apra Harbour

# %%
serie = pd.read_csv('apra_harbour.csv')
serie
# Out:
#                       Time  Precipitation
# 0      1998-01-01 00:00:00           0.00
# 1      1998-01-01 03:00:00           0.12
# 2      1998-01-01 06:00:00           0.00
# 3      1998-01-01 09:00:00           0.00
# 4      1998-01-01 12:00:00           0.00
# ...                    ...            ...
# 63292  2019-08-30 12:00:00           0.00
# 63293  2019-08-30 15:00:00           0.00
# 63294  2019-08-30 18:00:00           0.00
# 63295  2019-08-30 21:00:00           0.00
# 63296  2019-08-31 00:00:00           0.00
#
# [63297 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
fig, ax = plt.subplots()
ax.plot_date(pd.to_datetime(serie['Time']), serie.Precipitation, '-')
ax.xaxis.set_major_locator(dates.YearLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y'))
plt.tight_layout()
plt.title("Apra Harbour's Rainfall 1998-2019")
plt.show()

# %% [markdown]
# # Kaneohe

# %%
serie = pd.read_csv('kaneohe.csv')
serie
# Out:
#                       Time  Precipitation
# 0      1998-01-01 00:00:00           0.03
# 1      1998-01-01 03:00:00           0.00
# 2      1998-01-01 06:00:00           0.00
# 3      1998-01-01 09:00:00           0.00
# 4      1998-01-01 12:00:00           0.03
# ...                    ...            ...
# 63292  2019-08-30 12:00:00           0.00
# 63293  2019-08-30 15:00:00           0.00
# 63294  2019-08-30 18:00:00           0.00
# 63295  2019-08-30 21:00:00           0.00
# 63296  2019-08-31 00:00:00           0.00
#
# [63297 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
fig, ax = plt.subplots()
ax.plot_date(pd.to_datetime(serie['Time']), serie.Precipitation, '-')
ax.xaxis.set_major_locator(dates.YearLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y'))
plt.tight_layout()
plt.title("Kaneohe's Rainfall 1998-2019")
plt.show()
